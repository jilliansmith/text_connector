# %%
# !python -m spacy download en
# Out:
#     Downloading en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz
#
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz (52.2MB)
#     100% |████████████████████████████████| 52.2MB 91.8MB/s ta 0:00:011
#   Requirement already satisfied (use --upgrade to upgrade): en-core-web-sm==1.2.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz in /srv/app/venv/lib/python3.6/site-packages
# Requirement already satisfied: spacy<2.0.0,>=1.7.0 in /srv/app/venv/lib/python3.6/site-packages (from en-core-web-sm==1.2.0)
# Requirement already satisfied: numpy>=1.7 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: murmurhash<0.27,>=0.26 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: cymem<1.32,>=1.30 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: thinc<6.6.0,>=6.5.0 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: pip<10.0.0,>=9.0.0 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: six in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: pathlib in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: ujson>=1.35 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: dill<0.3,>=0.2 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: regex<2017.12.1,>=2017.4.1 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: ftfy<5.0.0,>=4.4.2 in /srv/app/venv/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: wrapt in /srv/app/venv/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /srv/app/venv/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /srv/app/venv/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: termcolor in /srv/app/venv/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: idna<2.7,>=2.5 in /srv/app/venv/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /srv/app/venv/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/app/venv/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /srv/app/venv/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: html5lib in /srv/app/venv/lib/python3.6/site-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: wcwidth in /srv/app/venv/lib/python3.6/site-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: toolz>=0.8.0 in /srv/app/venv/lib/python3.6/site-packages (from cytoolz<0.9,>=0.8->thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: setuptools>=18.5 in /srv/app/venv/lib/python3.6/site-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
# Requirement already satisfied: webencodings in /srv/app/venv/lib/python3.6/site-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0)
#
#     Linking successful
#
#     /srv/app/venv/lib/python3.6/site-packages/en_core_web_sm/en_core_web_sm-1.2.0
#     --> /srv/app/venv/lib/python3.6/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en').

# %% [markdown]
# # [SpaCy](https://spacy.io/): Industrial-Strength NLP
#
# The tradtional NLP library has always been [NLTK](http://www.nltk.org/). While `NLTK` is still very useful for linguistics analysis and exporation, `spacy` has become a nice option for easy and fast implementation of the NLP pipeline. What's the NLP pipeline? It's a number of common steps computational linguists perform to help them (and the computer) better understand textual data. Digital Humanists are often fond of the pipeline because it gives us more things to count! Let's what `spacy` can give us that we can count.

# %%
from datascience import *
import spacy

# %% [markdown]
# Let's start out with a short string from our reading and see what happens.

# %%
my_string = '''
"What are you going to do with yourself this evening, Alfred?" said Mr.
Royal to his companion, as they issued from his counting-house in New
Orleans. "Perhaps I ought to apologize for not calling you Mr. King,
considering the shortness of our acquaintance; but your father and I
were like brothers in our youth, and you resemble him so much, I can
hardly realize that you are not he himself, and I still a young man.
It used to be a joke with us that we must be cousins, since he was a
King and I was of the Royal family. So excuse me if I say to you, as
I used to say to him. What are you going to do with yourself, Cousin
Alfred?"

"I thank you for the friendly familiarity," rejoined the young man.
"It is pleasant to know that I remind you so strongly of my good
father. My most earnest wish is to resemble him in character as much
as I am said to resemble him in person. I have formed no plans for the
evening. I was just about to ask you what there was best worth seeing
or hearing in the Crescent City."'''.replace("\n", " ")

# %% [markdown]
# We've downloaded the English model, and now we just have to load it. This model will do ***everything*** for us, but we'll only get a little taste today.

# %%
#nlp = spacy.load('en')
nlp = spacy.load('en', parser=False)  # run this instead if you don't have > 1GB RAM

# %% [markdown]
# To parse an entire text we just call the model on a string.

# %%
parsed_text = nlp(my_string)
parsed_text
# Out:
#  "What are you going to do with yourself this evening, Alfred?" said Mr. Royal to his companion, as they issued from his counting-house in New Orleans. "Perhaps I ought to apologize for not calling you Mr. King, considering the shortness of our acquaintance; but your father and I were like brothers in our youth, and you resemble him so much, I can hardly realize that you are not he himself, and I still a young man. It used to be a joke with us that we must be cousins, since he was a King and I was of the Royal family. So excuse me if I say to you, as I used to say to him. What are you going to do with yourself, Cousin Alfred?"  "I thank you for the friendly familiarity," rejoined the young man. "It is pleasant to know that I remind you so strongly of my good father. My most earnest wish is to resemble him in character as much as I am said to resemble him in person. I have formed no plans for the evening. I was just about to ask you what there was best worth seeing or hearing in the Crescent City."

# %% [markdown]
# That was quick! So what happened? We've talked a lot about tokenizing, either in words or sentences.
#
# What about sentences?

# %%
sents_tab = Table()
sents_tab.append_column(label="Sentence", values=[sentence.text for sentence in parsed_text.sents])
sents_tab.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-58082b83b173> in <module>()
#       1 sents_tab = Table()
# ----> 2 sents_tab.append_column(label="Sentence", values=[sentence.text for sentence in parsed_text.sents])
#       3 sents_tab.show()
#
# <ipython-input-12-58082b83b173> in <listcomp>(.0)
#       1 sents_tab = Table()
# ----> 2 sents_tab.append_column(label="Sentence", values=[sentence.text for sentence in parsed_text.sents])
#       3 sents_tab.show()
#
# /srv/app/venv/lib/python3.6/site-packages/spacy/tokens/doc.pyx in __get__ (spacy/tokens/doc.cpp:9707)()
#
# ValueError: Sentence boundary detection requires the dependency parse, which requires data to be installed. For more info, see the documentation:
# https://spacy.io/docs/usage

# %% [markdown]
# Words?

# %%
toks_tab = Table()
toks_tab.append_column(label="Word", values=[word.text for word in parsed_text])
toks_tab.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Word</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>What        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>are         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>going       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>do          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>with        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>yourself    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>this        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>evening     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Alfred      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>?           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>said        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mr.         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Royal       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>his         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>companion   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>as          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>they        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>issued      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>from        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>his         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>counting    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>-           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>house       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>in          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>New         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Orleans     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Perhaps     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ought       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>apologize   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>for         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>not         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>calling     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mr.         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>King        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>considering </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>the         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>shortness   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>of          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>our         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>acquaintance</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>;           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>but         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>your        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>father      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>were        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>like        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>brothers    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>in          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>our         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>youth       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>resemble    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>him         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>so          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>much        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>can         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>hardly      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>realize     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>that        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>are         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>not         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>he          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>himself     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>still       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>a           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>young       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>man         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>It          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>used        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>be          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>a           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>joke        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>with        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>us          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>that        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>we          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>must        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>be          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>cousins     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>

# %% [markdown]
# What about parts of speech?

# %%
toks_tab.append_column(label="POS", values=[word.pos_ for word in parsed_text])
toks_tab.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Word</th> <th>POS</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>            </td> <td>SPACE</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>What        </td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>are         </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>going       </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td> <td>PART </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>do          </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>with        </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>yourself    </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>this        </td> <td>DET  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>evening     </td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Alfred      </td> <td>PROPN</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>?           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>said        </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mr.         </td> <td>PROPN</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Royal       </td> <td>PROPN</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>his         </td> <td>ADJ  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>companion   </td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>as          </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>they        </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>issued      </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>from        </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>his         </td> <td>ADJ  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>counting    </td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>-           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>house       </td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>in          </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>New         </td> <td>PROPN</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Orleans     </td> <td>PROPN</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Perhaps     </td> <td>ADV  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ought       </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td> <td>PART </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>apologize   </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>for         </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>not         </td> <td>ADV  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>calling     </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mr.         </td> <td>PROPN</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>King        </td> <td>PROPN</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>considering </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>the         </td> <td>DET  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>shortness   </td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>of          </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>our         </td> <td>ADJ  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>acquaintance</td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>;           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>but         </td> <td>CCONJ</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>your        </td> <td>ADJ  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>father      </td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and         </td> <td>CCONJ</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>were        </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>like        </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>brothers    </td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>in          </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>our         </td> <td>ADJ  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>youth       </td> <td>NOUN </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and         </td> <td>CCONJ</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>resemble    </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>him         </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>so          </td> <td>ADV  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>much        </td> <td>ADV  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>can         </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>hardly      </td> <td>ADV  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>realize     </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>that        </td> <td>ADP  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>are         </td> <td>VERB </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>not         </td> <td>ADV  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>he          </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>himself     </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and         </td> <td>CCONJ</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td> <td>PRON </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>still       </td> <td>ADV  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td

# %% [markdown]
# Lemmata?

# %%
toks_tab.append_column(label="Lemma", values=[word.lemma_ for word in parsed_text])
toks_tab.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Word</th> <th>POS</th> <th>Lemma</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>            </td> <td>SPACE</td> <td>            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td> <td>PUNCT</td> <td>"           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>What        </td> <td>NOUN </td> <td>what        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>are         </td> <td>VERB </td> <td>be          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td> <td>PRON </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>going       </td> <td>VERB </td> <td>go          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td> <td>PART </td> <td>to          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>do          </td> <td>VERB </td> <td>do          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>with        </td> <td>ADP  </td> <td>with        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>yourself    </td> <td>PRON </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>this        </td> <td>DET  </td> <td>this        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>evening     </td> <td>NOUN </td> <td>evening     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td> <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Alfred      </td> <td>PROPN</td> <td>alfred      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>?           </td> <td>PUNCT</td> <td>?           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td> <td>PUNCT</td> <td>"           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>said        </td> <td>VERB </td> <td>say         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mr.         </td> <td>PROPN</td> <td>mr.         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Royal       </td> <td>PROPN</td> <td>royal       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td> <td>ADP  </td> <td>to          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>his         </td> <td>ADJ  </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>companion   </td> <td>NOUN </td> <td>companion   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td> <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>as          </td> <td>ADP  </td> <td>as          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>they        </td> <td>PRON </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>issued      </td> <td>VERB </td> <td>issue       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>from        </td> <td>ADP  </td> <td>from        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>his         </td> <td>ADJ  </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>counting    </td> <td>NOUN </td> <td>counting    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>-           </td> <td>PUNCT</td> <td>-           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>house       </td> <td>NOUN </td> <td>house       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>in          </td> <td>ADP  </td> <td>in          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>New         </td> <td>PROPN</td> <td>new         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Orleans     </td> <td>PROPN</td> <td>orleans     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.           </td> <td>PUNCT</td> <td>.           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td> <td>PUNCT</td> <td>"           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Perhaps     </td> <td>ADV  </td> <td>perhaps     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td> <td>PRON </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ought       </td> <td>VERB </td> <td>ought       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td> <td>PART </td> <td>to          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>apologize   </td> <td>VERB </td> <td>apologize   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>for         </td> <td>ADP  </td> <td>for         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>not         </td> <td>ADV  </td> <td>not         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>calling     </td> <td>VERB </td> <td>call        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td> <td>PRON </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mr.         </td> <td>PROPN</td> <td>mr.         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>King        </td> <td>PROPN</td> <td>king        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td> <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>considering </td> <td>VERB </td> <td>consider    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>the         </td> <td>DET  </td> <td>the         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>shortness   </td> <td>NOUN </td> <td>shortness   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>of          </td> <td>ADP  </td> <td>of          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>our         </td> <td>ADJ  </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>acquaintance</td> <td>NOUN </td> <td>acquaintance</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>;           </td> <td>PUNCT</td> <td>;           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>but         </td> <td>CCONJ</td> <td>but         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>your        </td> <td>ADJ  </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>father      </td> <td>NOUN </td> <td>father      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and         </td> <td>CCONJ</td> <td>and         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I           </td> <td>PRON </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>were        </td> <td>VERB </td> <td>be          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>like        </td> <td>ADP  </td> <td>like        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>brothers    </td> <td>NOUN </td> <td>brother     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>in          </td> <td>ADP  </td> <td>in          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>our         </td> <td>ADJ  </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>youth       </td> <td>NOUN </td> <td>youth       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td> <td>,           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and         </td> <td>CCONJ</td> <td>and         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td> <td>PRON </td> <td>-PRON-      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>resemble    </td> <td>VERB </td> <td>resemble    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>him         </td> <td>PRON </td> <td>-PRON-

# %% [markdown]
# What else? Let's just make a function `tablefy` that will make a table of all this information for us:

# %%
def tablefy(parsed_text):
    toks_tab = Table()
    toks_tab.append_column(label="Word", values=[word.text for word in parsed_text])
    toks_tab.append_column(label="POS", values=[word.pos_ for word in parsed_text])
    toks_tab.append_column(label="Lemma", values=[word.lemma_ for word in parsed_text])
    toks_tab.append_column(label="Stop Word", values=[word.is_stop for word in parsed_text])
    toks_tab.append_column(label="Punctuation", values=[word.is_punct for word in parsed_text])
    toks_tab.append_column(label="Space", values=[word.is_space for word in parsed_text])
    toks_tab.append_column(label="Number", values=[word.like_num for word in parsed_text])
    toks_tab.append_column(label="OOV", values=[word.is_oov for word in parsed_text])
    toks_tab.append_column(label="Dependency", values=[word.dep_ for word in parsed_text])
    return toks_tab

# %%
tablefy(parsed_text).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Word</th> <th>POS</th> <th>Lemma</th> <th>Stop Word</th> <th>Punctuation</th> <th>Space</th> <th>Number</th> <th>OOV</th> <th>Dependency</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>            </td> <td>SPACE</td> <td>            </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td> <td>PUNCT</td> <td>"           </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>What        </td> <td>NOUN </td> <td>what        </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>are         </td> <td>VERB </td> <td>be          </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you         </td> <td>PRON </td> <td>-PRON-      </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>going       </td> <td>VERB </td> <td>go          </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td> <td>PART </td> <td>to          </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>do          </td> <td>VERB </td> <td>do          </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>with        </td> <td>ADP  </td> <td>with        </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>yourself    </td> <td>PRON </td> <td>-PRON-      </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>this        </td> <td>DET  </td> <td>this        </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>evening     </td> <td>NOUN </td> <td>evening     </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td> <td>,           </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Alfred      </td> <td>PROPN</td> <td>alfred      </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>?           </td> <td>PUNCT</td> <td>?           </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td> <td>PUNCT</td> <td>"           </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>said        </td> <td>VERB </td> <td>say         </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mr.         </td> <td>PROPN</td> <td>mr.         </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Royal       </td> <td>PROPN</td> <td>royal       </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to          </td> <td>ADP  </td> <td>to          </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>his         </td> <td>ADJ  </td> <td>-PRON-      </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>companion   </td> <td>NOUN </td> <td>companion   </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,           </td> <td>PUNCT</td> <td>,           </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>as          </td> <td>ADP  </td> <td>as          </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>they        </td> <td>PRON </td> <td>-PRON-      </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>issued      </td> <td>VERB </td> <td>issue       </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>from        </td> <td>ADP  </td> <td>from        </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>his         </td> <td>ADJ  </td> <td>-PRON-      </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>counting    </td> <td>NOUN </td> <td>counting    </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>-           </td> <td>PUNCT</td> <td>-           </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>house       </td> <td>NOUN </td> <td>house       </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>in          </td> <td>ADP  </td> <td>in          </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>New         </td> <td>PROPN</td> <td>new         </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Orleans     </td> <td>PROPN</td> <td>orleans     </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.           </td> <td>PUNCT</td> <td>.           </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"           </td> <td>PUNCT</td> <td>"           </td> <td>False    </td> <td>True       </td> <td>False</td> <td>Fal

# %% [markdown]
# ## Challenge
#
# What's the most common verb? Noun? What if you only include lemmata? What if you remove "stop words"?
#
# How would lemmatizing or removing "stop words" help us better understand a text over regular tokenizing?

# %%
tablefy(parsed_text).where('POS', 'VERB').group('Word').sort('count', descending=True)
# Out:
# Word     | count
# was      | 4
# resemble | 3
# are      | 3
# used     | 2
# say      | 2
# said     | 2
# is       | 2
# going    | 2
# do       | 2
# be       | 2
# ... (20 rows omitted)

# %%
tablefy(parsed_text).where('POS', 'NOUN').group('Word').sort('count', descending=True)
# Out:
# Word      | count
# man       | 2
# father    | 2
# evening   | 2
# What      | 2
# youth     | 1
# wish      | 1
# what      | 1
# shortness | 1
# plans     | 1
# person    | 1
# ... (11 rows omitted)

# %%
tablefy(parsed_text).group('Lemma').sort('count', descending=True)
# Out:
# Lemma  | count
# -PRON- | 43
# be     | 13
# to     | 12
# ,      | 10
# .      | 9
# "      | 8
# the    | 6
# in     | 5
# say    | 4
# as     | 4
# ... (85 rows omitted)

# %%
tablefy(parsed_text).where('Stop Word', False).group('Lemma').sort('count', descending=True)
# Out:
# Lemma    | count
# ,        | 10
# .        | 9
# "        | 8
# resemble | 3
# young    | 2
# say      | 2
# royal    | 2
# mr.      | 2
# man      | 2
# king     | 2
# ... (51 rows omitted)

# %% [markdown]
# ---
#
# ## Dependency Parsing
#
# Let's look at our text again:

# %%
parsed_text
# Out:
#  "What are you going to do with yourself this evening, Alfred?" said Mr. Royal to his companion, as they issued from his counting-house in New Orleans. "Perhaps I ought to apologize for not calling you Mr. King, considering the shortness of our acquaintance; but your father and I were like brothers in our youth, and you resemble him so much, I can hardly realize that you are not he himself, and I still a young man. It used to be a joke with us that we must be cousins, since he was a King and I was of the Royal family. So excuse me if I say to you, as I used to say to him. What are you going to do with yourself, Cousin Alfred?"  "I thank you for the friendly familiarity," rejoined the young man. "It is pleasant to know that I remind you so strongly of my good father. My most earnest wish is to resemble him in character as much as I am said to resemble him in person. I have formed no plans for the evening. I was just about to ask you what there was best worth seeing or hearing in the Crescent City."

# %% [markdown]
# Dependency parsing is one of the most useful and interesting NLP tools. A dependency parser will draw a tree of relationships between words. This is how you can find out specifically what adjectives are attributed to a specific person, what verbs are associated with a specific subject, etc.
#
# `spacy` provides an online visualizer named "displaCy" to visualize dependencies. Let's look at the [first sentence](https://demos.explosion.ai/displacy/?text=%22What%20are%20you%20going%20to%20do%20with%20yourself%20this%20evening%2C%20Alfred%3F%22%20said%20Mr.%20Royal%20to%20his%20companion%2C%20as%20they%20issued%20from%20his%20counting-house%20in%20New%20Orleans.&model=en&cpu=1&cph=1)
#
# ![alt text](img/dep_parse.png)
#
# We can loop through a dependency for a subject by checking the `head` attribute for the `pos` tag:

# %%
from spacy.symbols import nsubj, VERB

SV = []
for possible_subject in parsed_text:
    if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
        SV.append((possible_subject.text, possible_subject.head))

# %%
sv_tab = Table()
sv_tab.append_column(label="Subject", values=[x[0] for x in SV])
sv_tab.append_column(label="Verb", values=[x[1] for x in SV])
sv_tab.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Subject</th> <th>Verb</th>
#         </tr>
#     </thead>
#     <tbody>
# </table>

# %% [markdown]
# You can imagine that you could look over a large corpus to analyze first person, second person, and third person characterizations. Dependency parsers are also important for understanding and processing natural language, a question answering system for example. These models help the computer understand *what* the question is that is being asked.

# %% [markdown]
# ## Limitations
#
# How accurate are the models? What happens if we change the style of English we're working with?

# %%
shakespeare = '''
Tush! Never tell me; I take it much unkindly
That thou, Iago, who hast had my purse
As if the strings were thine, shouldst know of this.
'''

shake_parsed = nlp(shakespeare.strip())
tablefy(shake_parsed).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Word</th> <th>POS</th> <th>Lemma</th> <th>Stop Word</th> <th>Punctuation</th> <th>Space</th> <th>Number</th> <th>OOV</th> <th>Dependency</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Tush    </td> <td>NOUN </td> <td>tush    </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>!       </td> <td>PUNCT</td> <td>!       </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Never   </td> <td>ADV  </td> <td>never   </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>tell    </td> <td>VERB </td> <td>tell    </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>me      </td> <td>PRON </td> <td>-PRON-  </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>;       </td> <td>PUNCT</td> <td>;       </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I       </td> <td>PRON </td> <td>-PRON-  </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>take    </td> <td>VERB </td> <td>take    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>it      </td> <td>PRON </td> <td>-PRON-  </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>much    </td> <td>ADV  </td> <td>much    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>unkindly</td> <td>ADV  </td> <td>unkindly</td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>
#        </td> <td>SPACE</td> <td>
#        </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>That    </td> <td>ADP  </td> <td>that    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>thou    </td> <td>NOUN </td> <td>thou    </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,       </td> <td>PUNCT</td> <td>,       </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Iago    </td> <td>PROPN</td> <td>iago    </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,       </td> <td>PUNCT</td> <td>,       </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>who     </td> <td>NOUN </td> <td>who     </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>hast    </td> <td>VERB </td> <td>hast    </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>had     </td> <td>VERB </td> <td>have    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>my      </td> <td>ADJ  </td> <td>-PRON-  </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>purse   </td> <td>NOUN </td> <td>purse   </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>
#        </td> <td>SPACE</td> <td>
#        </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>As      </td> <td>ADP  </td> <td>as      </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>if      </td> <td>ADP  </td> <td>if      </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>the     </td> <td>DET  </td> <td>the     </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>strings </td> <td>NOUN </td> <td>string  </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>were    </td> <td>VERB </td> <td>be      </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>thine   </td> <td>NOUN </td> <td>thine   </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,       </td> <td>PUNCT</td> <td>,       </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>shouldst</td> <td>NOUN </td> <td>shouldst</td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>know    </td> <td>NOUN </td> <td>know    </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>of      </td> <td>ADP  </td> <td>of      </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>this    </td> <td>DET  </td> <td>this    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.       </td> <td>PUNCT</td> <td>.       </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
# </table>

# %%
huck_finn_jim = '''
“Who dah?” “Say, who is you?  Whar is you?  Dog my cats ef I didn’ hear sumf’n.
Well, I know what I’s gwyne to do:  I’s gwyne to set down here and listen tell I hears it agin.”"
'''

hf_parsed = nlp(huck_finn_jim.strip())
tablefy(hf_parsed).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Word</th> <th>POS</th> <th>Lemma</th> <th>Stop Word</th> <th>Punctuation</th> <th>Space</th> <th>Number</th> <th>OOV</th> <th>Dependency</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>“     </td> <td>PUNCT</td> <td>"     </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Who   </td> <td>NOUN </td> <td>who   </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>dah   </td> <td>NOUN </td> <td>dah   </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>?     </td> <td>PUNCT</td> <td>?     </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>”     </td> <td>PUNCT</td> <td>"     </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>“     </td> <td>PUNCT</td> <td>"     </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Say   </td> <td>PROPN</td> <td>say   </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,     </td> <td>PUNCT</td> <td>,     </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>who   </td> <td>NOUN </td> <td>who   </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>is    </td> <td>VERB </td> <td>be    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you   </td> <td>PRON </td> <td>-PRON-</td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>?     </td> <td>PUNCT</td> <td>?     </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>      </td> <td>SPACE</td> <td>      </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Whar  </td> <td>PROPN</td> <td>whar  </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>is    </td> <td>VERB </td> <td>be    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you   </td> <td>PRON </td> <td>-PRON-</td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>?     </td> <td>PUNCT</td> <td>?     </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>      </td> <td>SPACE</td> <td>      </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Dog   </td> <td>PROPN</td> <td>dog   </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>my    </td> <td>ADJ  </td> <td>-PRON-</td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>cats  </td> <td>NOUN </td> <td>cat   </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ef    </td> <td>ADP  </td> <td>ef    </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I     </td> <td>PRON </td> <td>-PRON-</td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>didn’ </td> <td>VERB </td> <td>didn’ </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>hear  </td> <td>VERB </td> <td>hear  </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>sumf’n</td> <td>NOUN </td> <td>sumf’n</td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.     </td> <td>PUNCT</td> <td>.     </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>
#      </td> <td>SPACE</td> <td>
#      </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Well  </td> <td>INTJ </td> <td>well  </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,     </td> <td>PUNCT</td> <td>,     </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I     </td> <td>PRON </td> <td>-PRON-</td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>know  </td> <td>VERB </td> <td>know  </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>what  </td> <td>NOUN </td> <td>what  </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I     </td> <td>PRON </td> <td>-PRON-</td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>’s    </td> <td>VERB </td> <td>’     </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>gwyne </td> <td>NOUN </td> <td>gwyne </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to    </td> <td>PART </td> <td>to    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>do    </td> <td>VERB </td> <td>do    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td

# %%
text_speech = '''
LOL where r u rn? omg that's sooo funnnnnny. c u in a sec.
'''
ts_parsed = nlp(text_speech.strip())
tablefy(ts_parsed).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Word</th> <th>POS</th> <th>Lemma</th> <th>Stop Word</th> <th>Punctuation</th> <th>Space</th> <th>Number</th> <th>OOV</th> <th>Dependency</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>LOL      </td> <td>PROPN</td> <td>lol      </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>where    </td> <td>ADV  </td> <td>where    </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>r        </td> <td>NOUN </td> <td>r        </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>u        </td> <td>X    </td> <td>u        </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>rn       </td> <td>NOUN </td> <td>rn       </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>?        </td> <td>PUNCT</td> <td>?        </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>omg      </td> <td>NOUN </td> <td>omg      </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>that     </td> <td>ADJ  </td> <td>that     </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>'s       </td> <td>VERB </td> <td>be       </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>sooo     </td> <td>ADJ  </td> <td>sooo     </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>funnnnnny</td> <td>NOUN </td> <td>funnnnnny</td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.        </td> <td>PUNCT</td> <td>.        </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>c        </td> <td>PUNCT</td> <td>c        </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>u        </td> <td>NOUN </td> <td>u        </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>in       </td> <td>ADP  </td> <td>in       </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>a        </td> <td>DET  </td> <td>a        </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>sec      </td> <td>NOUN </td> <td>sec      </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.        </td> <td>PUNCT</td> <td>.        </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
# </table>

# %%
old_english = '''
þæt wearð underne      eorðbuendum, 
þæt meotod hæfde      miht and strengðo 
ða he gefestnade      foldan sceatas. 
'''
oe_parsed = nlp(old_english.strip())
tablefy(oe_parsed).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Word</th> <th>POS</th> <th>Lemma</th> <th>Stop Word</th> <th>Punctuation</th> <th>Space</th> <th>Number</th> <th>OOV</th> <th>Dependency</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>þæt        </td> <td>NOUN </td> <td>þæt        </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>wearð      </td> <td>NOUN </td> <td>wearð      </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>underne    </td> <td>ADJ  </td> <td>underne    </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>           </td> <td>SPACE</td> <td>           </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>eorðbuendum</td> <td>NOUN </td> <td>eorðbuendum</td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>,          </td> <td>PUNCT</td> <td>,          </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>
#           </td> <td>SPACE</td> <td>
#           </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>þæt        </td> <td>NOUN </td> <td>þæt        </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>meotod     </td> <td>NOUN </td> <td>meotod     </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>hæfde      </td> <td>NOUN </td> <td>hæfde      </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>           </td> <td>SPACE</td> <td>           </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>miht       </td> <td>NOUN </td> <td>miht       </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and        </td> <td>CCONJ</td> <td>and        </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>strengðo   </td> <td>NOUN </td> <td>strengðo   </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>
#           </td> <td>SPACE</td> <td>
#           </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ða         </td> <td>ADP  </td> <td>ða         </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>he         </td> <td>PRON </td> <td>-PRON-     </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>gefestnade </td> <td>VERB </td> <td>gefestnade </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>           </td> <td>SPACE</td> <td>           </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>foldan     </td> <td>ADJ  </td> <td>foldan     </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>sceatas    </td> <td>NOUN </td> <td>sceata     </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>True </td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>.          </td> <td>PUNCT</td> <td>.          </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## NER and Civil War-Era Novels
#
# Wilkens uses a technique called "NER", or "Named Entity Recognition" to let the computer identify all of the geographic place names. Wilkens writes:
#
# > Text strings representing named locations in the corpus were identified using
# the named entity recognizer of the Stanford CoreNLP package with supplied training
# data. To reduce errors and to narrow the results for human review, only those
# named-location strings that occurred at least five times in the corpus and were used
# by at least two different authors were accepted. The remaining unique strings were
# reviewed by hand against their context in each source volume. [883]
#
# While we don't have the time for a human review right now, `spacy` does allow us to annotate place names (among other things!) in the same fashion as Stanford CoreNLP (a native Java library):

# %%
ner_tab = Table()
ner_tab.append_column(label="NER Label", values=[ent.label_ for ent in parsed_text.ents])
ner_tab.append_column(label="NER Text", values=[ent.text for ent in parsed_text.ents])
ner_tab.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>NER Label</th> <th>NER Text</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>TIME     </td> <td>this evening </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON   </td> <td>Alfred       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON   </td> <td>Royal        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>GPE      </td> <td>New Orleans  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON   </td> <td>King         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORG      </td> <td>Royal        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON   </td> <td>Alfred       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>GPE      </td> <td>Crescent City</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# Cool! It's identified a few types of things for us. We can check what these mean [here](https://spacy.io/docs/usage/entity-recognition#entity-types). `GPE` is country, cities, or states. Seems like that's what Wilkens was using.
#
# Since we don't have his corpus of 1000 novels, let's just take our reading, *A Romance of the Republic*, as an example. We can use the `requests` library to get the raw `HTML` of a web page, and if we take the `.text` property we can make this a nice string.

# %%
import requests

text = requests.get("http://www.gutenberg.org/files/10549/10549.txt").text
text = text[1050:].replace('\r\n', ' ')  # fix formatting and skip title header
print(text[:5000])
# Out:
#  CHAPTER I.   "What are you going to do with yourself this evening, Alfred?" said Mr. Royal to his companion, as they issued from his counting-house in New Orleans. "Perhaps I ought to apologize for not calling you Mr. King, considering the shortness of our acquaintance; but your father and I were like brothers in our youth, and you resemble him so much, I can hardly realize that you are not he himself, and I still a young man. It used to be a joke with us that we must be cousins, since he was a King and I was of the Royal family. So excuse me if I say to you, as I used to say to him. What are you going to do with yourself, Cousin Alfred?"  "I thank you for the friendly familiarity," rejoined the young man. "It is pleasant to know that I remind you so strongly of my good father. My most earnest wish is to resemble him in character as much as I am said to resemble him in person. I have formed no plans for the evening. I was just about to ask you what there was best worth seeing or hearing in the Crescent City."  "If I should tell you I thought there was nothing better worth seeing than my daughters, you would perhaps excuse a father's partiality," rejoined Mr. Royal.  "Your daughters!" exclaimed his companion, in a tone of surprise. "I never heard that you were married."  A shadow of embarrassment passed over the merchant's face, as he replied, "Their mother was a Spanish lady,--a stranger here,--and she formed no acquaintance. She was a woman of a great heart and of rare beauty. Nothing can ever make up her loss to me; but all the joy that remains in life is centred in the daughters she has left me. I should like to introduce them to you; and that is a compliment I never before paid to any young man. My home is in the outskirts of the city; and when we have dined at the hotel, according to my daily habit, I will send off a few letters, and then, if you like to go there with me, I will call a carriage."  "Thank you," replied the young man; "unless it is your own custom to ride, I should prefer to walk. I like the exercise, and it will give a better opportunity to observe the city, which is so different from our Northern towns that it has for me the attractions of a foreign land."  In compliance with this wish, Mr. Royal took him through the principal streets, pointing out the public buildings, and now and then stopping to smile at some placard or sign which presented an odd jumble of French and English. When they came to the suburbs of the city, the aspect of things became charmingly rural. Houses were scattered here and there among trees and gardens. Mr. Royal pointed out one of them, nestled in flowers and half encircled by an orange-grove, and said, "That is my home. When I first came here, the place where it stands was a field of sugar-canes; but the city is fast stretching itself into the suburbs."  They approached the dwelling; and in answer to the bell, the door was opened by a comely young negress, with a turban of bright colors on her head and golden hoops in her ears. Before the gentlemen had disposed of their hats and canes, a light little figure bounded from one of the rooms, clapping her hands, and exclaiming, "Ah, Papasito!" Then, seeing a stranger with him, she suddenly stood still, with a pretty look of blushing surprise.  "Never mind, Mignonne," said her father, fondly patting her head. "This is Alfred Royal King, from Boston; my namesake, and the son of a dear old friend of mine. I have invited him to see you dance. Mr. King, this is my Floracita."  The fairy dotted a courtesy, quickly and gracefully as a butterfly touching a flower, and then darted back into the room she had left. There they were met by a taller young lady, who was introduced as "My daughter Rosabella." Her beauty was superlative and peculiar. Her complexion was like a glowing reflection upon ivory from gold in the sunshine. Her large brown eyes were deeply fringed, and lambent with interior light. Lustrous dark brown hair shaded her forehead ...

# %% [markdown]
# We'll leave the chapter headers for now, it shouldn't affect much. Now we need to parse this with that `nlp` function:

# %%
parsed = nlp(text)

# %% [markdown]
# ## Challenge
#
# With this larger string, find the most common noun, verb, and adjective. Then explore the other features of `spacy` and see what you can discover about our reading:

# %%
tablefy(parsed).show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Word</th> <th>POS</th> <th>Lemma</th> <th>Stop Word</th> <th>Punctuation</th> <th>Space</th> <th>Number</th> <th>OOV</th> <th>Dependency</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>       </td> <td>SPACE</td> <td>       </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CHAPTER</td> <td>NOUN </td> <td>chapter</td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>I.     </td> <td>NOUN </td> <td>i.     </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>       </td> <td>SPACE</td> <td>       </td> <td>False    </td> <td>False      </td> <td>True </td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>"      </td> <td>PUNCT</td> <td>"      </td> <td>False    </td> <td>True       </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>What   </td> <td>NOUN </td> <td>what   </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>are    </td> <td>VERB </td> <td>be     </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>you    </td> <td>PRON </td> <td>-PRON- </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>going  </td> <td>VERB </td> <td>go     </td> <td>False    </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>to     </td> <td>PART </td> <td>to     </td> <td>True     </td> <td>False      </td> <td>False</td> <td>False </td> <td>False</td> <td>          </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (159911 rows omitted)</p

# %%
tablefy(parsed).where('POS', 'NOUN').group('Word').sort('count', descending=True)
# Out:
# Word   | count
# who    | 269
# what   | 192
# father | 190
# time   | 177
# man    | 152
# lady   | 144
# hand   | 143
# mother | 134
# friend | 134
# day    | 132
# ... (4161 rows omitted)

# %%
tablefy(parsed).where('POS', 'VERB').group('Word').sort('count', descending=True)
# Out:
# Word  | count
# was   | 1712
# had   | 994
# be    | 757
# is    | 729
# have  | 725
# said  | 671
# were  | 566
# would | 474
# will  | 461
# do    | 402
# ... (3046 rows omitted)

# %%
tablefy(parsed).where('POS', 'ADJ').group('Word').sort('count', descending=True)
# Out:
# Word   | count
# her    | 1399
# his    | 887
# my     | 634
# your   | 369
# their  | 358
# little | 322
# which  | 251
# such   | 239
# that   | 235
# young  | 209
# ... (1654 rows omitted)

# %%
ner_table = Table()
ner_table.append_column(label="NER Label", values=[ent.label_ for ent in parsed.ents])
ner_table.append_column(label="NER Text", values=[ent.text for ent in parsed.ents])
ner_table.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>NER Label</th> <th>NER Text</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>TIME       </td> <td>this evening                                                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Alfred                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Royal                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>GPE        </td> <td>New Orleans                                                 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>King                                                        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORG        </td> <td>Royal                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Alfred                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>GPE        </td> <td>Crescent City                                               </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Royal                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>NORP       </td> <td>Spanish                                                     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>WORK_OF_ART</td> <td>Thank you                                                   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Royal                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>LANGUAGE   </td> <td>French                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>LANGUAGE   </td> <td>English                                                     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Royal                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CARDINAL   </td> <td>one                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CARDINAL   </td> <td>half                                                        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORDINAL    </td> <td>first                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CARDINAL   </td> <td>one                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Papasito                                                    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Mignonne                                                    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Alfred Royal King                                           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>GPE        </td> <td>Boston                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>King                                                        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORG        </td> <td>Floracita                                                   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Rosabella                                                   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CARDINAL   </td> <td>one                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td> Floracita                                                  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>WORK_OF_ART</td> <td>Cupid's bow                                                 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>NORP       </td> <td>French                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Alfred King                                                 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CARDINAL   </td> <td>one                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Flora                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Canova                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>WORK_OF_ART</td> <td>Dancer in Repose                                            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>GPE        </td> <td>France                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Rosabella                                                   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Floracita                                                   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORG        </td> <td>the Temple of                                               </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Flora                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Alfred                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Royal                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Floracita                                                   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORG        </td> <td>Mamita                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORG        </td> <td>the Temple of                                               </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Flora                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Papasito                                                    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Mamita                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DATE       </td> <td>two years ago                                               </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Alfred                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Flora                                                       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORG        </td> <td>Floracita                                                   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>GPE        </td> <td>Papasito                                                    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Mamita                                                      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PERSON     </td> <td>Pensee Vivace_."                                            </td>
#         </tr

# %%
ner_table.where('NER Label', 'GPE').group('NER Text').sort('count', descending=True)
# Out:
# NER Text          | count
# Tulee             | 64
# New Orleans       | 63
# Boston            | 58
# Nassau            | 25
# Savannah          | 21
# Rome              | 20
# New York          | 19
# France            | 19
# Eulalia           | 19
# the United States | 16
# ... (137 rows omitted)

# %% [markdown]
# ---
#
# Let's continue in the fashion that Wilkens did and extract the named entities, specifically those for "GPE". We can loop through each entity, and if it is labeled as `GPE` we'll add it to our `places` list. We'll then make a `Counter` object out of that to get the frequency of each place name.

# %%
from collections import Counter

places = []

for ent in parsed.ents:
    if ent.label_ == "GPE":
        places.append(ent.text.strip())

places = Counter(places)
places.most_common()
# Out:
# [('Tulee', 64),
#  ('New Orleans', 63),
#  ('Boston', 58),
#  ('Nassau', 25),
#  ('Savannah', 21),
#  ('Rome', 20),
#  ('France', 19),
#  ('Eulalia', 19),
#  ('New York', 19),
#  ('the United States', 16),
#  ('South', 13),
#  ('Italy', 12),
#  ('Paris', 11),
#  ('Thistle', 11),
#  ('Signor', 9),
#  ('Papasito', 8),
#  ('Magnolia Lawn', 8),
#  ('Tulipa', 7),
#  ('England', 7),
#  ('Massachusetts', 7),
#  ('Carolina', 7),
#  ('Floracita', 6),
#  ('Georgia', 6),
#  ('Washington', 6),
#  ('Northampton', 6),
#  ('Henriet', 6),
#  ('Louisiana', 4),
#  ('_', 4),
#  ('Java', 4),
#  ('America', 4),
#  ('New Rochelle', 4),
#  ('Mozart', 3),
#  ('Rosabella', 3),
#  ('Providence', 3),
#  ('Marseilles', 3),
#  ('Damascus', 3),
#  ('Natchez', 3),
#  ('Oriental', 2),
#  ('Rosamunda', 2),
#  ('Moorish', 2),
#  ('Thou', 2),
#  ('Savannah to', 2),
#  ('Arkansas', 2),
#  ('Paradise', 2),
#  ('Magnolia', 2),
#  ('Virginia', 2),
#  ('the Free States', 2),
#  ('the Southern States', 2),
#  ('Florence', 2),
#  ('Frascati', 2),
#  ('Puritan', 2),
#  ('Florimond', 2),
#  ('Whittier', 2),
#  ('New Bedford', 2),
#  ('Naples', 2),
#  ('Alhambra', 2),
#  ('Divine', 2),
#  ('Mount Holyoke', 2),
#  ('Caroliny', 2),
#  ('Mississippi', 2),
#  ('G.F.', 2),
#  ('U.S.', 2),
#  ('Crescent City', 1),
#  ('Taglioni', 1),
#  ('Buona Notte', 1),
#  ('West Indies', 1),
#  ('St. Augustine', 1),
#  ('Canova', 1),
#  ('La Bayadere', 1),
#  ('Venice', 1),
#  ('Battledoor', 1),
#  ('Cher', 1),
#  ('Buenas', 1),
#  ('Youth', 1),
#  ('Mamita', 1),
#  ('Signor Papanti', 1),
#  ('Yankeedom', 1),
#  ('Thoroughly', 1),
#  ('Madame Guirlande', 1),
#  ('Pyrus Japonica', 1),
#  ('Savannah and Rosa', 1),
#  ('Albiness', 1),
#  ('Alfred', 1),
#  ('Beaufort', 1),
#  ('Welby', 1),
#  ('Bella Rosa', 1),
#  ('Rosalinda', 1),
#  ('Garden', 1),
#  ('Eden', 1),
#  ('heaven', 1),
#  ('Jove', 1),
#  ('Spain', 1),
#  ('South Carolina', 1),
#  ('the South of France', 1),
#  ('Egypt', 1),
#  ('Smyrna', 1),
#  ('Madame Gonsalez', 1),
#  ('Holy Land', 1),
#  ('Philadelphia', 1),
#  ('Switzerland', 1),
#  ('Albano', 1),
#  ('Aeneas', 1),
#  ('Eternal City', 1),
#  ('Campagna', 1),
#  ('Vatican', 1),
#  ('Boston ice', 1),
#  ('Andalusia', 1),
#  ('Civita Vecchia', 1),
#  ('North', 1),
#  ('Buzzard', 1),
#  ('Capri', 1),
#  ('Honiton', 1),
#  ('Newfoundland', 1),
#  ('Rose Royal', 1),
#  ('Norma', 1),
#  ('Cambridge', 1),
#  ('Alabama', 1),
#  ('Vermont', 1),
#  ('Scripture', 1),
#  ('Satan', 1),
#  ('Manon', 1),
#  ('Buenos dias', 1),
#  ('Querida', 1),
#  ('Beaufort on', 1),
#  ('Dreadful', 1),
#  ('Germany', 1),
#  ('Connecticut', 1),
#  ('Scotch', 1),
#  ('Mount Himalaya', 1),
#  ('Cuba', 1),
#  ('Deacon', 1),
#  ('Calcutta', 1),
#  ('Guinea', 1),
#  ('Shebee', 1),
#  ('New York city', 1),
#  ('Bull Run', 1),
#  ('Mount Auburn', 1),
#  ('Beethoven', 1),
#  ('Slavery', 1),
#  ('St. George', 1),
#  ('Jerusalem', 1),
#  ('the Republic of that', 1),
#  ('Hallelujah', 1),
#  ('Wilton', 1),
#  ('a United States', 1),
#  ('PARAGRAPH F3', 1),
#  ('PG', 1)]

# %% [markdown]
# That looks OK, but it's pretty rough! Keep this in mind when using trained models. They aren't 100% accurate. That's why Wilkens went through by hand after to get rid of the garbage.
#
# If you thought NER was cool, wait for this. Now that we have a list of "places", we can send that to an online database to get back latitude and longitude coordinates (much like Wilkens used Google's geocoder), along with the US state. To make sure it's actually a US state, we'll need a list to compare to. So let's load that:

# %%
with open('data/us_states.txt', 'r') as f:
    states = f.read().split('\n')
    states = [x.strip() for x in states]

states
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %% [markdown]
# OK, now we're ready. The `Nominatim` function from the `geopy` library will return an object that has the properties we want. We'll append a new row to our table for each entry. Importantly, we're using the `keys` of the `places` counter because we don't need to ask the database for "New Orleans" 10 times to get the location. So after we get the information we'll just add as many rows as the counter tells us there are.

# %%
from geopy.geocoders import Nominatim
from datascience import *
import time

geolocator = Nominatim(timeout=10)

geo_tab = Table(["latitude", "longitude", "name", "state"])

for name in places.keys():  # only want to loop through unique place names to call once per place name
    print("Getting information for " + name + "...")
    
    # finds the lat and lon of each name in the locations list
    location = geolocator.geocode(name)

    try:
        # index the raw response for lat and lon
        lat = float(location.raw["lat"])
        lon = float(location.raw["lon"])
        
        # string manipulation to find state name
        for p in location.address.split(","):
            if p.strip() in states:
                state = p.strip()
                break

        # add to our table
        for i in range(places[name] - 1):
            geo_tab.append(Table.from_records([{"name": name,
                                          "latitude": lat,
                                          "longitude": lon,
                                          "state": state}]).row(0))
    except:
        pass
# Out:
# Getting information for New Orleans...
# Getting information for Crescent City...
# Getting information for Boston...
# Getting information for France...
# Getting information for Papasito...
# Getting information for Floracita...
# Getting information for Taglioni...
# Getting information for Italy...
# Getting information for Mozart...
# Getting information for Buona Notte...
# Getting information for West Indies...
# Getting information for Tulipa...
# Getting information for Oriental...
# Getting information for St. Augustine...
# Getting information for Paris...
# Getting information for Eulalia...
# Getting information for Louisiana...
# Getting information for Canova...
# Getting information for La Bayadere...
# Getting information for Venice...
# Getting information for Battledoor...
# Getting information for Cher...
# Getting information for _...
# Getting information for Buenas...
# Getting information for Rosabella...
# Getting information for Youth...
# Getting information for New York...
# Getting information for Mamita...
# Getting information for Signor...
# Getting information for Tulee...
# Getting information for Nassau...
# Getting information for Savannah...
# Getting information for Georgia...
# Getting information for Signor Papanti...
# Getting information for Yankeedom...
# Getting information for Thoroughly...
# Getting information for Thistle...
# Getting information for Madame Guirlande...
# Getting information for Rosamunda...
# Getting information for Moorish...
# Getting information for Pyrus Japonica...
# Getting information for Thou...
# Getting information for Java...
# Getting information for Savannah and Rosa...
# Getting information for Savannah to...
# Getting information for Arkansas...
# Getting information for Albiness...
# Getting information for Alfred...
# Getting information for Beaufort...
# Getting information for Paradise...
# Getting information for Providence...
# Getting information for Welby...
# Getting information for Bella Rosa...
# Getting information for Magnolia...
# Getting information for Magnolia Lawn...
# Getting information for Rosalinda...
# Getting information for Garden...
# Getting information for Eden...
# Getting information for Virginia...
# Getting information for heaven...
# Getting information for Jove...
# Getting information for Spain...
# Getting information for the Free States...
# Getting information for South Carolina...
# Getting information for the Southern States...
# Getting information for the United States...
# Getting information for South...
# Getting information for the South of France...
# Getting information for Egypt...
# Getting information for Florence...
# Getting information for Smyrna...
# Getting information for Madame Gonsalez...
# Getting information for Holy Land...
# Getting information for Marseilles...
# Getting information for Philadelphia...
# Getting information for England...
# Getting information for Switzerland...
# Getting information for Rome...
# Getting information for Albano...
# Getting information for Aeneas...
# Getting information for Frascati...
# Getting information for Eternal City...
# Getting information for Campagna...
# Getting information for Vatican...
# Getting information for Boston ice...
# Getting information for America...
# Getting information for Puritan...
# Getting information for Andalusia...
# Getting information for Civita Vecchia...
# Getting information for North...
# Getting information for Florimond...
# Getting information for Buzzard...
# Getting information for Whittier...
# Getting information for New Bedford...
# Getting information for Naples...
# Getting information for Capri...
# Getting information for Alhambra...
# Getting information for Washington...
# Getting information for Damascus...
# Getting information for Honiton...
# Getting information for Northampton...
# Getting information for Newfoundland...
# Getting information for Rose Royal...
# Getting information for Norma...
# Getting information for Cambridge...
# Getting information for Massachusetts...
# Getting information for Alabama...
# Getting information for Carolina...
# Getting information for Vermont...
# Getting information for Divine...
# Getting information for Scripture...
# Getting information for Satan...
# Getting information for Mount Holyoke...
# Getting information for Manon...
# Getting information for Buenos dias...
# Getting information for Querida...
# Getting information for Beaufort on...
# Getting information for Dreadful...
# Getting information for Germany...
# Getting information for Connecticut...
# Getting information for Scotch...
# Getting information for Mount Himalaya...
# Getting information for Cuba...
# Getting information for Deacon...
# Getting information for Caroliny...
# Getting information for Mississippi...
# Getting information for Calcutta...
# Getting information for Natchez...
# Getting information for Guinea...
# Getting information for Shebee...
# Getting information for G.F....
# Getting information for New Rochelle...
# Getting information for Henriet...
# Getting information for New York city...
# Getting information for Bull Run...
# Getting information for Mount Auburn...
# Getting information for Beethoven...
# Getting information for Slavery...
# Getting information for St. George...
# Getting information for Jerusalem...
# Getting information for the Republic of that...
# Getting information for Hallelujah...
# Getting information for Wilton...
# Getting information for a United States...
# Getting information for PARAGRAPH F3...
# Getting information for U.S....
# Getting information for PG...

# %%
geo_tab.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>latitude</th> <th>longitude</th> <th>name</th> <th>state</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29.9499 </td> <td>-90.0701 </td> <td>New Orleans        </td> <td>Louisiana     </td>
#         </tr>
#     </tbody>
#         <tr

# %% [markdown]
# Now we can plot a nice [choropleth](https://en.wikipedia.org/wiki/Choropleth_map).

# %%
# %matplotlib inline

from scripts.choropleth import us_choropleth
us_choropleth(geo_tab)

# %% [markdown]
# ---
#
# # Homework:
#
# Find the text to three different Civil War-Era (1851-1875) novels on [Project Gutenberg](https://www.gutenberg.org/) (maybe mentioned in our reading?!). Make sure you click for the `.txt` files, and use a `GET` request from the `requests` library to get the text.
#
# First do some exploration on parts of speech. Then combine the NER location frequencies and plot a choropleth. Look closely at the words plotted. How did the NER model do? How does your choropleth look compared to Wilkens'?

# %%
uncle_toms_cabin = requests.get('https://www.gutenberg.org/files/203/203-0.txt').text

roughing_it = requests.get('https://www.gutenberg.org/files/3177/3177.txt').text

the_marble_faun = requests.get('https://www.gutenberg.org/files/2181/2181-0.txt').text

all_texts = uncle_toms_cabin + roughing_it + the_marble_faun
parsed_all = nlp(all_texts)
tablefy(parsed_all)
# Out:
# Word      | POS   | Lemma     | Stop Word | Punctuation | Space | Number | OOV   | Dependency
# ﻿The      | DET   | ﻿the      | False     | False       | False | False  | True  |
# Project   | PROPN | project   | False     | False       | False | False  | False |
# Gutenberg | PROPN | gutenberg | False     | False       | False | False  | False |
# EBook     | PROPN | ebook     | False     | False       | False | False  | True  |
# of        | ADP   | of        | True      | False       | False | False  | False |
# Uncle     | PROPN | uncle     | False     | False       | False | False  | False |
# Tom       | PROPN | tom       | False     | False       | False | False  | False |
# ’s        | PROPN | ’s        | False     | False       | False | False  | False |
# Cabin     | PROPN | cabin     | False     | False       | False | False  | False |
# ,         | PUNCT | ,         | False     | True        | False | False  | False |
# ... (553970 rows omitted)

# %%
places_two = []

for ent in parsed_all.ents:
    if ent.label_ == "GPE":
        places_two.append(ent.text.strip())
        
places_two = Counter(places_two)
places_two.most_common()
# Out:
# [('', 394),
#  ('St. Clare', 131),
#  ('Rome', 86),
#  ('Virginia', 56),
#  ('Nevada', 55),
#  ('Topsy', 54),
#  ('California', 50),
#  ('Kentucky', 49),
#  ('San Francisco', 47),
#  ('the United States', 33),
#  ('New Orleans', 28),
#  ('America', 27),
#  ('Legree', 27),
#  ('Arkansas', 26),
#  ('New York', 23),
#  ('Donatello', 21),
#  ('the', 20),
#  ('Canada', 20),
#  ('â\x80\x9d', 20),
#  ('Honolulu', 18),
#  ('Ohio', 17),
#  ('England', 15),
#  ('Italy', 15),
#  ('Emmeline', 14),
#  ('Utah', 14),
#  ('China', 13),
#  ('Eliza', 12),
#  ('Providence', 12),
#  ('Mississippi', 12),
#  ('Vermont', 11),
#  ('Jerusalem', 11),
#  ('U.S.', 11),
#  ('Carson City', 11),
#  ('Washington', 10),
#  ('Cincinnati', 9),
#  ('Missouri', 9),
#  ('Whiteman', 9),
#  ('Hawaii', 9),
#  ('Louisville', 8),
#  ('Sabbath', 8),
#  ('United\r\nStates', 8),
#  ('Territory', 8),
#  ('Kentuck', 7),
#  ('Louisiana', 7),
#  ('Satan', 7),
#  ('Thou', 7),
#  ('France', 7),
#  ('Quimbo', 7),
#  ('Higbie', 7),
#  ('Virginia City', 7),
#  ('Mono Lake', 7),
#  ('Trevi', 7),
#  ('a', 6),
#  ('Mas’r', 6),
#  ('heaven', 6),
#  ('Christianity', 6),
#  ('South', 6),
#  ('Massachusetts', 6),
#  ('Montana', 6),
#  ('St. Louis', 6),
#  ('United States', 6),
#  ('Sacramento', 6),
#  ('Nephi', 6),
#  ('Ophir', 6),
#  ('Natchez', 5),
#  ('Hebrew', 5),
#  ('”', 5),
#  ('Paradise', 5),
#  ('Bible', 5),
#  ('Mammy', 5),
#  ('Eden', 5),
#  ('Egypt', 5),
#  ('States', 5),
#  ('Pears', 5),
#  ('Illinois', 5),
#  ('Chinaman', 5),
#  ('Pennsylvania', 5),
#  ('Kanaka', 5),
#  ('Canaan', 4),
#  ('Boston', 4),
#  ('Adolph', 4),
#  ('Sambo', 4),
#  ('Amherstberg', 4),
#  ('Platte', 4),
#  ('Kansas', 4),
#  ('St. Joseph', 4),
#  ('Julesburg', 4),
#  ('Placerville', 4),
#  ('Washoe', 4),
#  ('The United States', 4),
#  ('Esmeralda', 4),
#  ('Silver City', 4),
#  ('Dollinger', 4),
#  ('Kingâ\x80\x99s', 4),
#  ('Greeley', 4),
#  ('Florence', 4),
#  ('Donatello’s', 4),
#  ('Orleans', 3),
#  ('Spring', 3),
#  ('Shelby County', 3),
#  ('Africa', 3),
#  ('Quakeress', 3),
#  ('India', 3),
#  ('Moorish', 3),
#  ('Spain', 3),
#  ('Phineas', 3),
#  ('Cousin', 3),
#  ('Kintuck', 3),
#  ('city', 3),
#  ('it', 3),
#  ('Israel', 3),
#  ('Montreal', 3),
#  ('Liberia', 3),
#  ('a United States', 3),
#  ('Gutenberg', 3),
#  ('PARAGRAPH F3', 3),
#  ('Fairbanks', 3),
#  ('AK', 3),
#  ('PG', 3),
#  ('Overland City', 3),
#  ('Scriptural', 3),
#  ('Brigham Young', 3),
#  ('Erie', 3),
#  ('Unionville', 3),
#  ('Austin', 3),
#  ('â\x80\x9cWell', 3),
#  ('Noakes', 3),
#  ('Mount Davidson', 3),
#  ('Ajax', 3),
#  ('Charleston', 3),
#  ('Kona', 3),
#  ('Kailua', 3),
#  ('Roman', 3),
#  ('Arcadia', 3),
#  ('Kenyon’s', 3),
#  ('Carrara', 3),
#  ('Newfoundland', 2),
#  ('Mas’r’s', 2),
#  ('T----', 2),
#  ('Jordan', 2),
#  ('Loker', 2),
#  ('her', 2),
#  ('Columbus', 2),
#  ('Cudjoe', 2),
#  ('Testament', 2),
#  ('Oaklands', 2),
#  ('New Testament', 2),
#  ('Indiana', 2),
#  ('Flint', 2),
#  ('New', 2),
#  ('Austria', 2),
#  ('Oxford', 2),
#  ('Madras', 2),
#  ('Quashy', 2),
#  ('Sodom', 2),
#  ('Gomorrah', 2),
#  ('Mozart', 2),
#  ('Divine', 2),
#  ('Misse', 2),
#  ('Cassy', 2),
#  ('Mas’r Legree', 2),
#  ('New Hampshire', 2),
#  ('Island', 2),
#  ('Nebraska', 2),
#  ('Syria', 2),
#  ('Omaha', 2),
#  ('Moab', 2),
#  ('Humph', 2),
#  ('Lake City', 2),
#  ('Moroni', 2),
#  ('Ether', 2),
#  ('Goshoots', 2),
#  ('Humboldt', 2),
#  ('Star City', 2),
#  ('Humboldt county', 2),
#  ('Carson city', 2),
#  ('Tennessee', 2),
#  ('â\x80\x9cNo', 2),
#  ('San', 2),
#  ('Mexico', 2),
#  ('Silverland', 2),
#  ('Peru', 2),
#  ('Greenland', 2),
#  ('Jacops', 2),
#  ('Billings', 2),
#  ('Oakland', 2),
#  ('Tuolumne', 2),
#  ('â\x80\x98nâ\x80\x99', 2),
#  ('South Carolina', 2),
#  ('Carolina', 2),
#  ('A', 2),
#  ('Kamehameha', 2),
#  ('Kohala', 2),
#  ('Captain', 2),
#  ('Michigan', 2),
#  ('Herculaneum', 2),
#  ('Maui', 2),
#  ('Haleakala', 2),
#  ('Lahaina', 2),
#  ('Iowa', 2),
#  ('by--', 2),
#  ('Great\r\nBritain', 2),
#  ('Kenyon', 2),
#  ('Virgin', 2),
#  ('Hilda’s', 2),
#  ('Gaul', 2),
#  ('Nymph', 2),
#  ('Trajan', 2),
#  ('Curtius', 2),
#  ('P----', 1),
#  ('Orleans--‘t was', 1),
#  ('a devil', 1),
#  ('Whitney’s', 1),
#  ('Uncle', 1),
#  ('his', 1),
#  ('Mas’r Georgey', 1),
#  ('boy', 1),
#  ('La, Aunt Chloe', 1),
#  ('New Jerusalem', 1),
#  ('gettin’ Tom', 1),
#  ('kickin’', 1),
#  ('Pearl River', 1),
#  ('Mobile', 1),
#  ('Marks--', 1),
#  ('Bible I', 1),
#  ('Cudjoe’s', 1),
#  ('the Southern States', 1),
#  ('a fair', 1),
#  ('Yer', 1),
#  ('N----', 1),
#  ('Hagar', 1),
#  ('Philadelphia', 1),
#  ('Clarksons', 1),
#  ('Wilberforces', 1),
#  ('our', 1),
#  ('Simeon', 1),
#  ('Morocco', 1),
#  ('re’ly', 1),
#  ('Lake', 1),
#  ('Pontchartrain', 1),
#  ('Paradise Lost,', 1),
#  ('Polly,', 1),
#  ('Master’s', 1),
#  ('Sheba', 1),
#  ('Solomon', 1),
#  ('Carthage', 1),
#  ('here,”--and', 1),
#  ('Lor', 1),
#  ('Shelby county', 1),
#  ('_Magna Charta', 1),
#  ('Regius', 1),
#  ('Cunning', 1),
#  ('New\r\nOrleans', 1),
#  ('low', 1),
#  ('Greek', 1),
#  ('Poland', 1),
#  ('Ireland', 1),
#  ('Abolition', 1),
#  ('’s', 1),
#  ('Canton', 1),
#  ('Haiti', 1),
#  ('Toussaint', 1),
#  ('Auguste', 1),
#  ('Paris', 1),
#  ('Jesus', 1),
#  ('Lazarus', 1),
#  ('death,’', 1),
#  ('Tantus', 1),
#  ('Heaven', 1),
#  ('Briskness', 1),
#  ('Spoilt', 1),
#  ('the Bible', 1),
#  ('a quick', 1),
#  ('Legree’s', 1),
#  ('Emmeline’s', 1),
#  ('Britain', 1),
#  ('Sandusky', 1),
#  ('Almighty', 1),
#  ('Utmost', 1),
#  ('Misse Cassy', 1),
#  ('but', 1),
#  ('Cassy’s', 1),
#  ('Hulloa', 1),
#  ('“Jesus', 1),
#  ('him', 1),
#  ('Hayti', 1),
#  ('New Englander', 1),
#  ('Shelby', 1),
#  ('Mas’r George', 1),
#  ('the District of Columbia', 1),
#  ('Pearl', 1),
#  ('Connecticut', 1),
#  ('Maine', 1),
#  ('North and South', 1),
#  ('Genial Comrade', 1),
#  ('Wild Mexican Mules', 1),
#  ('Overland City--', 1),
#  ('Buffalo', 1),
#  ('York City--', 1),
#  ('Specimen City', 1),
#  ('Virginia City--Washing Bills--', 1),
#  ('Chinatown', 1),
#  ('Hong Wo', 1),
#  ('See Yup', 1),
#  ('Roving', 1),
#  ('Holeakala', 1),
#  ('Treasurer', 1),
#  ('Comptroller', 1),
#  ('St. Jo', 1),
#  ('Brigham', 1),
#  ('Cottonwood', 1),
#  ('Marysville', 1),
#  ('North Platte', 1),
#  ('Ethiop', 1),
#  ('Palestine', 1),
#  ('Holy Land', 1),
#  ('Bashan', 1),
#  ('Bethlehem', 1),
#  ('Jericho', 1),
#  ('Israel!--guiding', 1),
#  ('â\x80\x9cJulesburg', 1),
#  ('â\x80\x9cOverland City', 1),
#  ('South Platte', 1),
#  ('Siam', 1),
#  ('Bangkok', 1),
#  ('St. Joe to', 1),
#  ('â\x80\x9cskipping', 1),
#  ('Rocky Mountain', 1),
#  ('Rocky Ridge', 1),
#  ('Fort Kearney', 1),
#  ('Main', 1),
#  ('Pfouts', 1),
#  ('Horse Creek', 1),
#  ('Sweetwater Creek', 1),
#  ('Independence Rock', 1),
#  ('Great\r\nSalt Lake City', 1),
#  ('Mount Washington', 1),
#  ('Yellowstone', 1),
#  ('Fort Bridger', 1),
#  ('Echo Canyon', 1),
#  ('sixty United States soldiers from Camp Floyd.  The day before, they had\r\nfired upon three hundred or four hundred Indians, whom they supposed\r\ngathered together for no good purpose.  In the fight that had ensued,\r\nfour Indians were captured, and the main body chased four miles, but\r\nnobody killed.  This looked like business.  We had a notion to get out\r\nand join the sixty soldiers, but upon reflecting that there were four\r\nhundred of the Indians, we concluded to go on and join the Indians.\r\n\r\nEcho Canyon is twenty miles long.  It was like a long, smooth, narrow\r\nstreet, with a gradual descending grade, and shut in by enormous\r\nperpendicular walls of coarse conglomerate, four hundred feet high in\r\nmany places, and turreted like mediaeval castles.  This was the most\r\nfaultless piece of road in the mountains, and the driver said he would\r\nâ\x80\x9clet his team out.â\x80\x9d  He did, and if the Pacific express trains whiz\r\nthrough there now any faster than we did then in the stage-coach, I envy\r\nthe passengers the exhilaration of it.  We fairly seemed to pick up our\r\nwheels and fly--and the mail matter was lifted up free from everything\r\nand held in solution!  I am not given to exaggeration, and when I say a\r\nthing I mean it.\r\n\r\nHowever, time presses.  At four in the afternoon we arrived on the summit\r\nof Big Mountain, fifteen miles from Salt Lake City, when all the world\r\nwas glorified with the setting sun, and the most stupendous panorama of\r\nmountain peaks yet encountered burst on our sight.  We looked out upon\r\nthis sublime spectacle from under the arch of a brilliant rainbow!  Even\r\nthe overland stage-driver stopped his horses and gazed!\r\n\r\nHalf an hour or an hour later, we changed horses, and took supper with a\r\nMormon â\x80\x9cDestroying Angel.â\x80\x9d\r\n\r\nâ\x80\x9cDestroying Angels,â\x80\x9d as I understand it, are Latter-Day Saints who are\r\nset apart by the Church to conduct permanent disappearances of obnoxious\r\ncitizens.  I had heard a deal about these Mormon Destroying Angels and\r\nthe dark and bloody deeds they had done, and when I entered this oneâ\x80\x99s\r\nhouse I had my shudder all ready.  But alas for all our romances, he was\r\nnothing but a loud, profane, offensive, old blackguard!  He was murderous\r\nenough, possibly, to fill the bill of a Destroyer, but would you have any\r\nkind of an Angel devoid of dignity?  Could you abide an Angel in an\r\nunclean shirt and no suspenders?  Could you respect an Angel with a\r\nhorse-laugh and a swagger like a buccaneer?\r\n\r\nThere were other blackguards present--comrades of this one.  And there\r\nwas one person that looked like a gentleman--Heber C. Kimballâ\x80\x99s son, tall\r\nand well made, and thirty years old, perhaps.  A lot of slatternly women\r\nflitted hither and thither in a hurry, with coffee-pots, plates of bread,\r\nand other appurtenances to supper, and these were said to be the wives of\r\nthe Angel--or some of them, at least.  And of course they were; for if\r\nthey had been hired â\x80\x9chelpâ\x80\x9d they would not have let an angel from above\r\nstorm and swear at them as he did, let alone one from the place this one\r\nhailed from.\r\n\r\nThis was our first experience of the western â\x80\x9cpeculiar institution,â\x80\x9d and\r\nit was not very prepossessing.  We did not tarry long to observe it, but\r\nhurried on to the home of the Latter-Day Saints, the stronghold of the\r\nprophets, the capital of the only absolute monarch in America--Great Salt\r\nLake City.  As the night closed in we took sanctuary in the Salt Lake\r\nHouse and unpacked our baggage.\r\n\r\n\r\n\r\n\r\nCHAPTER XIII.\r\n\r\nWe had a fine supper, of the freshest meats and fowls and vegetables--a\r\ngreat variety and as great abundance.  We walked about the streets some,\r\nafterward, and glanced in at shops and stores; and there was fascination\r\nin surreptitiously staring at every creature we took to be a M ...
#   1),
#  ('Brigham Young!--these', 1),
#  ('B. ]', 1),
#  ('Brigham Youngâ\x80\x99s', 1),
#  ('Shade of', 1),
#  ('MORMON', 1),
#  ('UPON', 1),
#  ('SR', 1),
#  ('Jarom', 1),
#  ('Zeniff', 1),
#  ('Helaman', 1),
#  ('Kumen', 1),
#  ('Saviour', 1),
#  ('â\x80\x9cRamah', 1),
#  ('Corihor', 1),
#  ('Ripliancum', 1),
#  ('Coriantumr', 1),
#  ('Salt Lake', 1),
#  ('Mountain', 1),
#  ('â\x80\x9cCamp Floyd', 1),
#  ('Sahara', 1),
#  ('Rocky Canyon', 1),
#  ('South Africa', 1),
#  ('Norway', 1),
#  ('District', 1),
#  ('Baltimore', 1),
#  ('Ragtown', 1),
#  ('Denver', 1),
#  ('Colorado', 1),
#  ('Talmud', 1),
#  ('Nevada Territory', 1),
#  ('Brigade', 1),
#  ('Johnny', 1),
#  ('America!â\x80\x9d', 1),
#  ('Genuine', 1),
#  ('Injun', 1),
#  ('Carson county', 1),
#  ('1858', 1),
#  ('â\x80\x9cCarson County', 1),
#  ('Chaplain', 1),
#  ('Golconda', 1),
#  ('Liverpool', 1),
#  ('the District Recorderâ\x80\x99s', 1),
#  ('â\x80\x9cfeetâ\x80\x9d', 1),
#  ('Delilah', 1),
#  ('â\x80\x9cBoomerang', 1),
#  ('the â\x80\x9cGreat Republic', 1),
#  ('â\x80\x9cArkansas', 1),
#  ('America!--and', 1),
#  ('Fatigue', 1),
#  ('Ollendorff', 1),
#  ('Carson', 1),
#  ('Washoe District', 1),
#  ('three', 1),
#  ('General', 1),
#  ('Hoosac Tunnel', 1),
#  ('Welchâ\x80\x99s', 1),
#  ('Mono', 1),
#  ('Summer', 1),
#  ('Germany', 1),
#  ('Switzerland', 1),
#  ('Greece, Palestine', 1),
#  ('Arabia', 1),
#  ('Persia', 1),
#  ('Gardinerâ\x80\x99s', 1),
#  ('Cairo', 1),
#  ('Beirut', 1),
#  ('Esmeralda District', 1),
#  ('Virginian', 1),
#  ('the Esmeralda Union', 1),
#  ('Eureka', 1),
#  ('Truckee', 1),
#  ('the\r\nUnion', 1),
#  ('â\x80\x9cGenesseeâ\x80\x9d', 1),
#  ('City Surveyor', 1),
#  ('Mount', 1),
#  ('Davidson', 1),
#  ('â\x80\x9csaltingâ\x80\x9d', 1),
#  ('â\x80\x9cmain', 1),
#  ('C', 1),
#  ('a state', 1),
#  ('Upper', 1),
#  ('Taylor', 1),
#  ('Gold Hill', 1),
#  ('Stockton', 1),
#  ('â\x80\x9cMr', 1),
#  ('Berlin city', 1),
#  ('Bermuda', 1),
#  ('Icebergs', 1),
#  ('Scotty', 1),
#  ('Faderland', 1),
#  ('Pistols', 1),
#  ('Gumbert', 1),
#  ('Reederâ\x80\x99s leg', 1),
#  ('Great Neptune', 1),
#  ('â\x80\x9d--and', 1),
#  ('New Bedford', 1),
#  ('North Atlantic', 1),
#  ('Behringâ\x80\x99s Strait', 1),
#  ('Albany', 1),
#  ('â\x80\x9cAlas', 1),
#  ('Dayton, Empire City', 1),
#  ('New Yorkâ\x80\x99s', 1),
#  ('Washoe Lake', 1),
#  ('â\x80\x9cgalleryâ\x80\x9d', 1),
#  ('Filkins', 1),
#  ('Indiany', 1),
#  ('Wellsville', 1),
#  ('Maryland', 1),
#  ('Morgan county', 1),
#  ('Chinamen', 1),
#  ('â\x80\x9cHong Wo', 1),
#  ('CHINATOWN', 1),
#  ('No', 1),
#  ('Washoe Valley', 1),
#  ('Poverty', 1),
#  ('Bulwer', 1),
#  ('Dumas', 1),
#  ('Toodles', 1),
#  ('Vicksburg', 1),
#  ('Gettysburg', 1),
#  ('Calla', 1),
#  ('Fort Yuma', 1),
#  ('the Western', 1),
#  ('NEW YORK', 1),
#  ('New York City', 1),
#  ('Humboldt County', 1),
#  ('Kearney', 1),
#  ('Merchant', 1),
#  ('Hunger', 1),
#  ('Blucherâ\x80\x99s', 1),
#  ('shovelinâ\x80\x99', 1),
#  ('Calaveras county', 1),
#  ('â\x80\x9cpocketâ\x80\x9d', 1),
#  ('â\x80\x9cquartzâ\x80\x9d', 1),
#  ('Rockport', 1),
#  ('Chinadom', 1),
#  ('Brannan', 1),
#  ('Nuuanu Valley', 1),
#  ('Micronesia', 1),
#  ('America.â\x80\x9d', 1),
#  ('Bibles', 1),
#  ('â\x80\x9cfinance', 1),
#  ('Undertaker', 1),
#  ('Arathea', 1),
#  ('Burlingame', 1),
#  ('Judged', 1),
#  ('Kaahumanu', 1),
#  ('Keeaumoku', 1),
#  ('Kaahumaunâ\x80\x99s', 1),
#  ('oneâ\x80\x99s', 1),
#  ('Islands', 1),
#  ('Sadowa', 1),
#  ('Campbellton,', 1),
#  ('â\x80\x99', 1),
#  ('Yours', 1),
#  ('Kealakekua', 1),
#  ('Obookia', 1),
#  ('Queen', 1),
#  ('the City of Refuge', 1),
#  ('a City of Refuge', 1),
#  ('Kanakas', 1),
#  ('Russia', 1),
#  ('Kilauea', 1),
#  ('N.Y.', 1),
#  ('London', 1),
#  ('lag', 1),
#  ('Ounaska', 1),
#  ('Japan', 1),
#  ('Nauvoo', 1),
#  ('Smithâ\x80\x99s', 1),
#  ('Deseret', 1),
#  ('Utahâ\x80\x9d', 1),
#  ('â\x80\x9cprophet', 1),
#  ('Cradlebaugh', 1),
#  ('Santa Clara', 1),
#  ('Storey County', 1),
#  ('noon', 1),
#  ('Yellow Jacket', 1),
#  ('Lynch', 1),
#  ('wonâ\x80\x99t', 1),
#  ('you---', 1),
#  ('Iâ\x80\x99m', 1),
#  ('â\x80\x9cBut', 1),
#  ('the People', 1),
#  ('THE CORSO', 1),
#  ('Antinous', 1),
#  ('Amazon', 1),
#  ('Romulus', 1),
#  ('Etruscan', 1),
#  ('Pentelic', 1),
#  ('Satyrs', 1),
#  ('Tieck', 1),
#  ('St. Calixtus', 1),
#  ('Memmius', 1),
#  ('one', 1),
#  ('Scripture', 1),
#  ('Naiad’s', 1),
#  ('Quirinal', 1),
#  ('Arcady', 1),
#  ('however', 1),
#  ('Unframed', 1),
#  ('Antoninus', 1),
#  ('Beholding', 1),
#  ('Vatican', 1),
#  ('Virgin’s', 1),
#  ('Eternal City', 1),
#  ('Tuscany', 1),
#  ('Trastevere', 1),
#  ('Algiers', 1),
#  ('Soracte', 1),
#  ('the Piazza del Popolo', 1),
#  ('Grey Friars Church', 1),
#  ('Comus', 1),
#  ('Benvenuto’s', 1),
#  ('Louvre', 1),
#  ('Bologna', 1),
#  ('Holy Week', 1),
#  ('Nature', 1),
#  ('St. Peter', 1),
#  ('Englishman', 1),
#  ('Venuses', 1),
#  ('Cupids', 1),
#  ('Bacchuses', 1),
#  ('Squalor', 1),
#  ('Bernini’s', 1),
#  ('Agrippa', 1),
#  ('Neptune', 1),
#  ('Fountain', 1),
#  ('Hadrian', 1),
#  ('Gothic', 1),
#  ('Benvenuto', 1),
#  ('Gauls', 1),
#  ('Caesar’s', 1),
#  ('Columbia', 1),
#  ('Column', 1),
#  ('Phocas', 1),
#  ('Augustan', 1),
#  ('Forum', 1),
#  ('Hilda', 1),
#  ('Capuchin', 1),
#  ('Michael’s', 1),
#  ('Golgotha', 1),
#  ('Brother Antonio', 1),
#  ('Visible', 1),
#  ('Edens', 1)]

# %%
from geopy.geocoders import Nominatim
from datascience import *
import time

geolocator = Nominatim(timeout=10)

geo_tab_two = Table(["latitude", "longitude", "name", "state"])

for name in places_two.keys():  # only want to loop through unique place names to call once per place name
    print("Getting information for " + name + "...")
    
    # finds the lat and lon of each name in the locations list
    location = geolocator.geocode(name)

    try:
        # index the raw response for lat and lon
        lat = float(location.raw["lat"])
        lon = float(location.raw["lon"])
        
        # string manipulation to find state name
        for p in location.address.split(","):
            if p.strip() in states:
                state = p.strip()
                break

        # add to our table
        for i in range(places_two[name] - 1):
            geo_tab_two.append(Table.from_records([{"name": name,
                                          "latitude": lat,
                                          "longitude": lon,
                                          "state": state}]).row(0))
    except:
        pass
    
geo_tab_two.show()
# Out:
# Getting information for the...
# Getting information for P----...
# Getting information for Kentucky...
# Getting information for ...
# Getting information for Orleans--‘t was...
# Getting information for Cincinnati...
# Getting information for Orleans...
# Getting information for Natchez...
# Getting information for a devil...
# Getting information for Eliza...
# Getting information for Whitney’s...
# Getting information for Canada...
# Getting information for Uncle...
# Getting information for Washington...
# Getting information for a...
# Getting information for his...
# Getting information for Mas’r Georgey...
# Getting information for boy...
# Getting information for La, Aunt Chloe...
# Getting information for New Jerusalem...
# Getting information for Canaan...
# Getting information for gettin’ Tom...
# Getting information for Newfoundland...
# Getting information for Mas’r...
# Getting information for Mas’r’s...
# Getting information for kickin’...
# Getting information for T----...
# Getting information for Ohio...
# Getting information for Jordan...
# Getting information for Spring...
# Getting information for Providence...
# Getting information for Loker...
# Getting information for New Orleans...
# Getting information for Pearl River...
# Getting information for Kentuck...
# Getting information for Shelby County...
# Getting information for Mobile...
# Getting information for Marks--...
# Getting information for Mississippi...
# Getting information for Bible I...
# Getting information for Cudjoe’s...
# Getting information for her...
# Getting information for Columbus...
# Getting information for heaven...
# Getting information for the Southern States...
# Getting information for a fair...
# Getting information for Cudjoe...
# Getting information for Hebrew...
# Getting information for Testament...
# Getting information for Yer...
# Getting information for ”...
# Getting information for N----...
# Getting information for Oaklands...
# Getting information for Hagar...
# Getting information for America...
# Getting information for Virginia...
# Getting information for Louisville...
# Getting information for New Testament...
# Getting information for Philadelphia...
# Getting information for Clarksons...
# Getting information for Wilberforces...
# Getting information for Africa...
# Getting information for our...
# Getting information for Quakeress...
# Getting information for Simeon...
# Getting information for Indiana...
# Getting information for Paradise...
# Getting information for Bible...
# Getting information for Morocco...
# Getting information for re’ly...
# Getting information for St. Clare...
# Getting information for Louisiana...
# Getting information for Vermont...
# Getting information for Lake...
# Getting information for Pontchartrain...
# Getting information for Paradise Lost,...
# Getting information for Flint...
# Getting information for the United States...
# Getting information for Boston...
# Getting information for New York...
# Getting information for India...
# Getting information for Moorish...
# Getting information for Spain...
# Getting information for Adolph...
# Getting information for Polly,...
# Getting information for Master’s...
# Getting information for Sheba...
# Getting information for Solomon...
# Getting information for Mammy...
# Getting information for Satan...
# Getting information for Christianity...
# Getting information for Eden...
# Getting information for Carthage...
# Getting information for here,”--and...
# Getting information for Lor...
# Getting information for Phineas...
# Getting information for New...
# Getting information for Thou...
# Getting information for Shelby county...
# Getting information for Austria...
# Getting information for Egypt...
# Getting information for South...
# Getting information for _Magna Charta...
# Getting information for Oxford...
# Getting information for Regius...
# Getting information for Madras...
# Getting information for Cunning...
# Getting information for England...
# Getting information for States...
# Getting information for New
# Orleans...
# Getting information for low...
# Getting information for Quashy...
# Getting information for Sodom...
# Getting information for Gomorrah...
# Getting information for Greek...
# Getting information for Poland...
# Getting information for Ireland...
# Getting information for Abolition...
# Getting information for ’s...
# Getting information for Topsy...
# Getting information for Cousin...
# Getting information for Canton...
# Getting information for Kintuck...
# Getting information for city...
# Getting information for Jerusalem...
# Getting information for France...
# Getting information for Haiti...
# Getting information for Toussaint...
# Getting information for Auguste...
# Getting information for Paris...
# Getting information for Jesus...
# Getting information for Pears...
# Getting information for it...
# Getting information for Lazarus...
# Getting information for death,’...
# Getting information for Mozart...
# Getting information for Tantus...
# Getting information for Heaven...
# Getting information for Divine...
# Getting information for Briskness...
# Getting information for Spoilt...
# Getting information for the Bible...
# Getting information for Legree...
# Getting information for Emmeline...
# Getting information for China...
# Getting information for Quimbo...
# Getting information for a quick...
# Getting information for Israel...
# Getting information for Misse...
# Getting information for Legree’s...
# Getting information for Sambo...
# Getting information for Sabbath...
# Getting information for Emmeline’s...
# Getting information for Cassy...
# Getting information for Mas’r Legree...
# Getting information for Britain...
# Getting information for Sandusky...
# Getting information for Amherstberg...
# Getting information for Almighty...
# Getting information for Utmost...
# Getting information for Misse Cassy...
# Getting information for but...
# Getting information for Cassy’s...
# Getting information for Hulloa...
# Getting information for “Jesus...
# Getting information for Rome...
# Getting information for him...
# Getting information for Montreal...
# Getting information for Hayti...
# Getting information for Liberia...
# Getting information for New Englander...
# Getting information for Shelby...
# Getting information for Mas’r George...
# Getting information for the District of Columbia...
# Getting information for Pearl...
# Getting information for Massachusetts...
# Getting information for New Hampshire...
# Getting information for Connecticut...
# Getting information for Maine...
# Getting information for North and South...
# Getting information for a United States...
# Getting information for Gutenberg...
# Getting information for United
# States...
# Getting information for PARAGRAPH F3...
# Getting information for U.S....
# Getting information for Fairbanks...
# Getting information for AK...
# Getting information for PG...
# Getting information for California...
# Getting information for Genial Comrade...
# Getting information for Nevada...
# Getting information for Wild Mexican Mules...
# Getting information for Overland City--...
# Getting information for Platte...
# Getting information for Buffalo...
# Getting information for Montana...
# Getting information for Higbie...
# Getting information for York City--...
# Getting information for Specimen City...
# Getting information for Virginia City--Washing Bills--...
# Getting information for Chinatown...
# Getting information for Hong Wo...
# Getting information for See Yup...
# Getting information for Virginia City...
# Getting information for San Francisco...
# Getting information for Roving...
# Getting information for Honolulu...
# Getting information for Island...
# Getting information for Holeakala...
# Getting information for Treasurer...
# Getting information for Comptroller...
# Getting information for Missouri...
# Getting information for St. Louis...
# Getting information for St. Jo...
# Getting information for Carson City...
# Getting information for United States...
# Getting information for Kansas...
# Getting information for Brigham...
# Getting information for Cottonwood...
# Getting information for Marysville...
# Getting information for Nebraska...
# Getting information for Syria...
# Getting information for North Platte...
# Getting information for Omaha...
# Getting information for Ethiop...
# Getting information for St. Joseph...
# Getting information for Sacramento...
# Getting information for Palestine...
# Getting information for Holy Land...
# Getting information for Bashan...
# Getting information for Bethlehem...
# Getting information for Jericho...
# Getting information for Moab...
# Getting information for Israel!--guiding...
# Getting information for Humph...
# Getting information for âJulesburg...
# Getting information for âOverland City...
# Getting information for Overland City...
# Getting information for South Platte...
# Getting information for â...
# Getting information for Siam...
# Getting information for Bangkok...
# Getting information for St. Joe to...
# Getting information for âskipping...
# Getting information for Julesburg...
# Getting information for Illinois...
# Getting information for Rocky Mountain...
# Getting information for Rocky Ridge...
# Getting information for Fort Kearney...
# Getting information for Main...
# Getting information for Pfouts...
# Getting information for Horse Creek...
# Getting information for Sweetwater Creek...
# Getting information for Independence Rock...
# Getting information for Great
# Salt Lake City...
# Getting information for Mount Washington...
# Getting information for Yellowstone...
# Getting information for Lake City...
# Getting information for Fort Bridger...
# Getting information for Echo Canyon...
# Getting information for sixty United States soldiers from Camp Floyd.  The day before, they had
# fired upon three hundred or four hundred Indians, whom they supposed
# gathered together for no good purpose.  In the fight that had ensued,
# four Indians were captured, and the main body chased four miles, but
# nobody killed.  This looked like business.  We had a notion to get out
# and join the sixty soldiers, but upon reflecting that there were four
# hundred of the Indians, we concluded to go on and join the Indians.
#
# Echo Canyon is twenty miles long.  It was like a long, smooth, narrow
# street, with a gradual descending grade, and shut in by enormous
# perpendicular walls of coarse conglomerate, four hundred feet high in
# many places, and turreted like mediaeval castles.  This was the most
# faultless piece of road in the mountains, and the driver said he would
# âlet his team out.â  He did, and if the Pacific express trains whiz
# through there now any faster than we did then in the stage-coach, I envy
# the passengers the exhilaration of it.  We fairly seemed to pick up our
# wheels and fly--and the mail matter was lifted up free from everything
# and held in solution!  I am not given to exaggeration, and when I say a
# thing I mean it.
#
# However, time presses.  At four in the afternoon we arrived on the summit
# of Big Mountain, fifteen miles from Salt Lake City, when all the world
# was glorified with the setting sun, and the most stupendous panorama of
# mountain peaks yet encountered burst on our sight.  We looked out upon
# this sublime spectacle from under the arch of a brilliant rainbow!  Even
# the overland stage-driver stopped his horses and gazed!
#
# Half an hour or an hour later, we changed horses, and took supper with a
# Mormon âDestroying Angel.â
#
# âDestroying Angels,â as I understand it, are Latter-Day Saints who are
# set apart by the Church to conduct permanent disappearances of obnoxious
# citizens.  I had heard a deal about these Mormon Destroying Angels and
# the dark and bloody deeds they had done, and when I entered this oneâs
# house I had my shudder all ready.  But alas for all our romances, he was
# nothing but a loud, profane, offensive, old blackguard!  He was murderous
# enough, possibly, to fill the bill of a Destroyer, but would you have any
# kind of an Angel devoid of dignity?  Could you abide an Angel in an
# unclean shirt and no suspenders?  Could you respect an Angel with a
# horse-laugh and a swagger like a buccaneer?
#
# There were other blackguards present--comrades of this one.  And there
# was one person that looked like a gentleman--Heber C. Kimballâs son, tall
# and well made, and thirty years old, perhaps.  A lot of slatternly women
# flitted hither and thither in a hurry, with coffee-pots, plates of bread,
# and other appurtenances to supper, and these were said to be the wives of
# the Angel--or some of them, at least.  And of course they were; for if
# they had been hired âhelpâ they would not have let an angel from above
# storm and swear at them as he did, let alone one from the place this one
# hailed from.
#
# This was our first experience of the western âpeculiar institution,â and
# it was not very prepossessing.  We did not tarry long to observe it, but
# hurried on to the home of the Latter-Day Saints, the stronghold of the
# prophets, the capital of the only absolute monarch in America--Great Salt
# Lake City.  As the night closed in we took sanctuary in the Salt Lake
# House and unpacked our baggage.
#
#
#
#
# CHAPTER XIII.
#
# We had a fine supper, of the freshest meats and fowls and vegetables--a
# great variety and as great abundance.  We walked about the streets some,
# afterward, and glanced in at shops and stores; and there was fascination
# in surreptitiously staring at every creature we took to be a Mormon.
# This was fairy-land to us, to all intents and purposes--a land of
# enchantment, and goblins, and awful mystery.  We felt a curiosity to ask
# every child how many mothers it had, and if it could tell them apart; and
# we experienced a thrill every time a dwelling-house door opened and shut
# as we passed, disclosing a glimpse of human heads and backs and
# shoulders--for we so longed to have a good satisfying look at a Mormon
# family in all its comprehensive ampleness, disposed in the customary
# concentric rings of its home circle.
#
# By and by the Acting Governor of the Territory introduced us to other
# âGentiles,â and we spent a sociable hour with them.  âGentilesâ are
# people who are not Mormons.  Our fellow-passenger, Bemis, took care of
# himself, during this part of the evening, and did not make an
# overpowering success of it, either, for he came into our room in the
# hotel about eleven oâclock, full of cheerfulness, and talking loosely,
# disjointedly and indiscriminately, and every now and then tugging out a
# ragged word by the roots that had more hiccups than syllables in it.
# This, together with his hanging his coat on the floor on one side of a
# chair, and his vest on the floor on the other side, and piling his pants
# on the floor just in front of the same chair, and then comtemplating the
# general result with superstitious awe, and finally pronouncing it âtoo
# many for himâ and going to bed with his boots on, led us to fear that
# something he had eaten had not agreed with him.
#
# But we knew afterward that it was something he had been drinking.  It was
# the exclusively Mormon refresher, âvalley tan.â
#
# Valley tan (or, at least, one form of valley tan) is a kind of whisky,
# or first cousin to it; is of Mormon invention and manufactured only in
# Utah.  Tradition says it is made of (imported) fire and brimstone.  If I
# remember rightly no public drinking saloons were allowed in the kingdom
# by Brigham Young, and no private drinking permitted among the faithful,
# except they confined themselves to âvalley tan.â
#
# Next day we strolled about everywhere through the broad, straight, level
# streets, and enjoyed the pleasant strangeness of a city of fifteen
# thousand inhabitants with no loafers perceptible in it; and no visible
# drunkards or noisy people; a limpid stream rippling and dancing through
# every street in place of a filthy gutter; block after block of trim
# dwellings, built of âframeâ and sunburned brick--a great thriving orchard
# and garden behind every one of them, apparently--branches from the street
# stream winding and sparkling among the garden beds and fruit trees--and a
# grand general air of neatness, repair, thrift and comfort, around and
# about and over the whole.  And everywhere were workshops, factories, and
# all manner of industries; and intent faces and busy hands were to be seen
# wherever one looked; and in oneâs ears was the ceaseless clink of
# hammers, the buzz of trade and the contented hum of drums and fly-wheels.
#
# The armorial crest of my own State consisted of two dissolute bears
# holding up the head of a dead and gone cask between them and making the
# pertinent remark, âUNITED, WE STAND--(hic!)--DIVIDED, WE FALL.â  It was
# always too figurative for the author of this book.  But the Mormon crest
# was easy.  And it was simple, unostentatious, and fitted like a glove.
# It was a representation of a GOLDEN BEEHIVE, with the bees all at work!
#
# The city lies in the edge of a level plain as broad as the State of
# Connecticut, and crouches close down to the ground under a curving wall
# of mighty mountains whose heads are hidden in the clouds, and whose
# shoulders bear relics of the snows of winter all the summer long.
#
# Seen from one of these dizzy heights, twelve or fifteen miles off, Great
# Salt Lake City is toned down and diminished till it is suggestive of a
# childâs toy-village reposing under the majestic protection of the Chinese
# wall.
#
# On some of those mountains, to the southwest, it had been raining every
# day for two weeks, but not a drop had fallen in the city.  And on hot
# days in late spring and early autumn the citizens could quit fanning and
# growling and go out and cool off by looking at the luxury of a glorious
# snow-storm going on in the mountains.  They could enjoy it at a distance,
# at those seasons, every day, though no snow would fall in their streets,
# or anywhere near them.
#
# Salt Lake City was healthy--an extremely healthy city.
#
# They declared there was only one physician in the place and he was
# arrested every week regularly and held to answer under the vagrant act
# for having âno visible means of support.â  They always give you a good
# substantial article of truth in Salt Lake, and good measure and good
# weight, too. [Very often, if you wished to weigh one of their airiest
# little commonplace statements you would want the hay scales.]
#
# We desired to visit the famous inland sea, the American âDead Sea,â the
# great Salt Lake--seventeen miles, horseback, from the city--for we had
# dreamed about it, and thought about it, and talked about it, and yearned
# to see it, all the first part of our trip; but now when it was only armâs
# length away it had suddenly lost nearly every bit of its interest.  And
# so we put it off, in a sort of general way, till next day--and that was
# the last we ever thought of it.  We dined with some hospitable Gentiles;
# and visited the foundation of the prodigious temple; and talked long with
# that shrewd Connecticut Yankee, Heber C. Kimball (since deceased), a
# saint of high degree and a mighty man of commerce.
#
# We saw the âTithing-House,â and the âLion House,â and I do not know or
# remember how many more church and government buildings of various kinds
# and curious names.  We flitted hither and thither and enjoyed every hour,
# and picked up a great deal of useful information and entertaining
# nonsense, and went to bed at night satisfied.
#
# The second day, we made the acquaintance of Mr. Street (since deceased)
# and put on white shirts and went and paid a state visit to the king.
# He seemed a quiet, kindly, easy-mannered, dignified, self-possessed old
# gentleman of fifty-five or sixty, and had a gentle craft in his eye that
# probably belonged there.  He was very simply dressed and was just taking
# off a straw hat as we entered.  He talked about Utah, and the Indians,
# and Nevada, and general American matters and questions, with our
# secretary and certain government officials who came with us.  But he
# never paid any attention to me, notwithstanding I made several attempts
# to âdraw him outâ on federal politics and his high handed attitude toward
# Congress.  I thought some of the things I said were rather fine.  But he
# merely looked around at me, at distant intervals, something as I have
# seen a benignant old cat look around to see which kitten was meddling
# with her tail.
#
# By and by I subsided into an indignant silence, and so sat until the end,
# hot and flushed, and execrating him in my heart for an ignorant savage.
# But he was calm.  His conversation with those gentlemen flowed on as
# sweetly and peacefully and musically as any summer brook.  When the
# audience was ended and we were retiring from the presence, he put his
# hand on my head, beamed down on me in an admiring way and said to my...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /srv/app/venv/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# /usr/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# /usr/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /usr/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 414: Request-URI Too Long
#
# During handling of the above exception, another exception occurred:
#
# GeocoderQueryError                        Traceback (most recent call last)
# <ipython-input-48-0a2056fca6cf> in <module>()
#      11
#      12     # finds the lat and lon of each name in the locations list
# ---> 13     location = geolocator.geocode(name)
#      14
#      15     try:
#
# /srv/app/venv/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     191         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     192         return self._parse_json(
# --> 193             self._call_geocoder(url, timeout=timeout), exactly_one
#     194         )
#     195
#
# /srv/app/venv/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     156                 code = error.getcode()
#     157                 try:
# --> 158                     raise ERROR_CODE_MAP[code](message)
#     159                 except KeyError:
#     160                     raise GeocoderServiceError(message)
#
# GeocoderQueryError: HTTP Error 414: Request-URI Too Long

# %%
us_choropleth(geo_tab_two)

# %% [markdown]
# The NER model did okay. It did catch a lot of the real locations from the texts passed through, however it included a LOT of fake locations or proper nouns that happened to be the names of citys, but weren't used in that context. Overall, I had a lot of the same problems that Wilkens encountered. Compared to Wilkens, my choropleth is a lot more centered on the west and mid-american states. I picked books set in those parts of the US however, and didn't include as many set in or written on the eastcoast, so this makes sense. My choropleth is also a lot messier, and includes a lot more fake data because I didn't go through manually and get rid of the false locations.
